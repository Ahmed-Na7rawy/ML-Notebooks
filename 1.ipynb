# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import numpy as np

# %%
df=pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.plot(df['YearsExperience'],df['Salary'],'g--')
plt.xticks(rotation=45)
plt.title('YearsExperince vs Salary')
plt.show()

# %%
plt.bar(df['YearsExperience'],df['Salary'])
plt.title('YearsExperince vs Salary')
plt.show()

# %%
plt.Figure(figsize=(10,5))
plt.Subplot(1,2,1)
plt.plot(df['YearsExperience'],df['Salary'],'g--')
plt.title('YearsExperince vs Salary')


plt.bar(df['YearsExperience'],df['Salary'])
plt.title('YearsExperince vs Salary')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.Figure(figsize=(10,5))
# ----> 2 plt.Subplot(1,2,1)
#       3 plt.plot(df['YearsExperience'],df['Salary'],'g--')
#       4 plt.xticks(rotation=45)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:641, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     639 else:
#     640     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#     643     raise ValueError('Width and height specified must be non-negative')
#
# ...

# %%
cars=['Ford','BMW','Volvo','Audi','Tesla']
values=[20,50,60,30,75]
colors=['brown','cyan','blue','indigo','gray']
explode=(0.1, 0.0, 0.2, 0.3, 0.0,)
plt.pie(values, labels=cars,colors=colors,autopct='%1.1f%%',explode=explode)
plt.legend(loc='center right',mode=expand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 6
#       4 explode=(0.1, 0.0, 0.2, 0.3, 0.0,)
#       5 plt.pie(values, labels=cars,colors=colors,autopct='%1.1f%%',explode=explode)
# ----> 6 plt.legend(loc='center right',mode=expand)
#
# NameError: name 'expand' is not defined

# %%
df=sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',data=df,hue='region')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
df1=pd.read_csv('diabetes.csv')
df1.describe().round()
df.columns
df.duplicated().sum()
# Out:
# 0
