# %% [markdown]
# # Credit Card Fraud Detection
#
# **Detecting fraudulent transactions using One-Class SVM anomaly detection**
#
# ---
#
# | Detail | Value |
# |--------|-------|
# | **Dataset** | Credit Card Fraud Detection (Kaggle) |
# | **Techniques** | One-Class SVM, StandardScaler, Anomaly Detection, Imbalanced Data |
# | **Author** | Ahmed Alnahrawy |

# %% [markdown]
# ## 1. Setup & Data Loading
#
# Import libraries and load the credit card transaction dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.svm import OneClassSVM
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('../data/creditcard.csv')
df.head

# %% [markdown]
# ## 2. Data Exploration
#
# Explore the highly imbalanced dataset and understand feature distributions.

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# ## 3. Preprocessing & Feature Scaling
#
# Standardize features and prepare data for anomaly detection.

# %%
df = df.drop(['Time'], axis=1)

# %%
scaler = StandardScaler()
df['Amount'] = scaler.fit_transform(df[['Amount']])

# %% [markdown]
# ## 4. One-Class SVM Training
#
# Train the anomaly detection model and evaluate performance.

# %%
train_data = df[df['Class'] == 0].sample(frac=0.1, random_state=42).drop(['Class'], axis=1)
model = OneClassSVM(kernel='rbf', nu=0.01)
model.fit(train_data)

# %%
predictions = model.predict(df.drop(['Class'], axis=1))
y_true = df['Class'].map({0: 1, 1: -1})

print(classification_report(y_true, predictions))

# %%
cm = confusion_matrix(y_true, predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.show()

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook demonstrated one-class svm, standardscaler, anomaly detection, imbalanced data techniques applied to the Credit Card Fraud Detection (Kaggle).
#
# **Author:** Ahmed Alnahrawy | [GitHub](https://github.com/Ahmed-Na7rawy)
